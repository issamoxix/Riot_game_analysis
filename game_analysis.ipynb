# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
games_csv_files = os.listdir('games')

# %%
path = f"games/{games_csv_files[0]}"
game_df = pd.read_csv(path)

# %%
game_df.head()
# Out:
#    assists  baronKills  bountyLevel  \
# 0       25           2            1
# 1       16           0            1
# 2        6           0            0
# 3       13           0            2
# 4       27           0            0
#
#                                           challenges  champExperience  \
# 0  {'12AssistStreakCount': 0, 'abilityUses': 545,...            19162
# 1  {'12AssistStreakCount': 0, 'abilityUses': 311,...            18359
# 2  {'12AssistStreakCount': 0, 'abilityUses': 435,...            20187
# 3  {'12AssistStreakCount': 0, 'abilityUses': 146,...            16673
# 4  {'12AssistStreakCount': 2, 'abilityUses': 282,...            15218
#
#    champLevel  championId championName  championTransform  \
# 0          18          20         Nunu                  0
# 1          17          62   MonkeyKing                  0
# 2          18          38     Kassadin                  0
# 3          17          51      Caitlyn                  0
# ...

# %%
game_df = game_df.convert_dtypes()

# %%
game_df.describe()
# Out:
#          assists  baronKills  bountyLevel  champExperience  champLevel  \
# count   10.00000   10.000000    10.000000        10.000000    10.00000
# unique       NaN         NaN          NaN              NaN         NaN
# top          NaN         NaN          NaN              NaN         NaN
# freq         NaN         NaN          NaN              NaN         NaN
# mean    12.80000    0.200000     0.400000     17159.300000    16.70000
# std      7.91342    0.632456     0.699206      2356.785666     1.05935
# min      5.00000    0.000000     0.000000     14371.000000    15.00000
# 25%      6.00000    0.000000     0.000000     15387.000000    16.00000
# 50%     12.00000    0.000000     0.000000     16209.000000    16.50000
# 75%     15.25000    0.000000     0.750000     18961.250000    17.75000
# max     27.00000    2.000000     2.000000     21082.000000    18.00000
#
#         championId  championTransform  consumablesPurchased  \
# ...
